# %%
import json
import pprint
from pymongo import MongoClient

# %%
#INICIAMOS MONGO CLIENT
client = MongoClient()

#Geodat es el nombre de la base
db= client.Geodat

#Geojsn es el nombre de la coleccion en donde se cargará el archivo .geojsn
dbp = db.Geojsn

data = open("carpetas-de-investigacion-pgj-de-la-ciudad-de-mexico.geojson")

x = json.load(data)

dbp.insert(x["features"])
# Out:
# C:\Users\Mauricio\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('5e287860d67a26c25eb0ebd1'),
#  ObjectId('5e287860d67a26c25eb0ebd2'),
#  ObjectId('5e287860d67a26c25eb0ebd3'),
#  ObjectId('5e287860d67a26c25eb0ebd4'),
#  ObjectId('5e287860d67a26c25eb0ebd5'),
#  ObjectId('5e287860d67a26c25eb0ebd6'),
#  ObjectId('5e287860d67a26c25eb0ebd7'),
#  ObjectId('5e287860d67a26c25eb0ebd8'),
#  ObjectId('5e287860d67a26c25eb0ebd9'),
#  ObjectId('5e287860d67a26c25eb0ebda'),
#  ObjectId('5e287860d67a26c25eb0ebdb'),
#  ObjectId('5e287860d67a26c25eb0ebdc'),
#  ObjectId('5e287860d67a26c25eb0ebdd'),
#  ObjectId('5e287860d67a26c25eb0ebde'),
#  ObjectId('5e287860d67a26c25eb0ebdf'),
#  ObjectId('5e287860d67a26c25eb0ebe0'),
#  ObjectId('5e287860d67a26c25eb0ebe1'),
#  ObjectId('5e287860d67a26c25eb0ebe2'),
#  ObjectId('5e287860d67a26c25eb0ebe3'),
#  ObjectId('5e287860d67a26c25eb0ebe4'),
# ...
